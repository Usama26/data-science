# %%
import pandas as pd

# %%
df1 = pd.read_csv('election_Pak/Kaggle v2 - Election Data.csv')

# %%
df2 = pd.read_csv('election_Pak/Kaggle v3 - Election Data.csv')

# %%
df3 = pd.read_csv('election_Pak/Kaggle v4 - Election Data.csv')

# %%
df1.head()
# Out:
#    S.No         Seat Constituency_title                  Candidate_Name  \
# 0     0   Peshawar I               NA-1         Muhammad Yousaf Khattak
# 1     1   Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan
# 2     2   Peshawar I               NA-1                       Jan Akbar
# 3     3  Peshawar II               NA-2    Arbab Mohammad Jehandir Khan
# 4     4  Peshawar II               NA-2            Arbab Saif-ur-Rahman
#
#     Party  Votes Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# 0  PML(Q)  44507             79847                 2688       82535
# 1     PNA  33964             79847                 2688       82535
# 2     IND   1376             79847                 2688       82535
# 3     PPP  32247             65825                 2155       67980
# 4     PNA  30268             65825                 2155       67980
#
#   Total_Registered_Voters Turnout  Election
# 0                  150063    0.55      1977
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0         Seat Constituency_title                  Candidate_Name  \
# 0           0   Peshawar I               NA-1         Muhammad Yousaf Khattak
# 1           1   Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan
# 2           2   Peshawar I               NA-1                       Jan Akbar
# 3           3  Peshawar II               NA-2    Arbab Mohammad Jehandir Khan
# 4           4  Peshawar II               NA-2            Arbab Saif-ur-Rahman
#
#     Party  Votes Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# 0  PML(Q)  44507             79847                 2688       82535
# 1     PNA  33964             79847                 2688       82535
# 2     IND   1376             79847                 2688       82535
# 3     PPP  32247             65825                 2155       67980
# 4     PNA  30268             65825                 2155       67980
#
#   Total_Registered_Voters Turnout  Election
# ...

# %%
df3.head()
# Out:
#    Unnamed: 0         Seat Constituency_title                  Candidate_Name  \
# 0           0   Peshawar-I               NA-1         Muhammad Yousaf Khattak
# 1           1   Peshawar-I               NA-1  Air Marshal (Retd) Asghar Khan
# 2           2   Peshawar-I               NA-1                       Jan Akbar
# 3           3  Peshawar-II               NA-2    Arbab Mohammad Jehandir Khan
# 4           4  Peshawar-II               NA-2            Arbab Saif-ur-Rahman
#
#     Party  Votes Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# 0  PML(Q)  44507             79847                 2688       82535
# 1     PNA  33964             79847                 2688       82535
# 2     IND   1376             79847                 2688       82535
# 3     PPP  32247             65825                 2155       67980
# 4     PNA  30268             65825                 2155       67980
#
#   Total_Registered_Voters Turnout  Election
# ...

# %%
df3.tail()
# Out:
#        Unnamed: 0                Seat Constituency_title  \
# 19712       15212  Lasbela-cum-Gwadar             NA-272
# 19713       15213  Lasbela-cum-Gwadar             NA-272
# 19714       15214  Lasbela-cum-Gwadar             NA-272
# 19715       15215  Lasbela-cum-Gwadar             NA-272
# 19716       15216  Lasbela-cum-Gwadar             NA-272
#
#                Candidate_Name                       Party  Votes  \
# 19712          Mohammad Akram         Pak Sarzameen Party    882
# 19713  Muhammad Akhtar mengal  Balochistan National Party  41866
# 19714      Nawab Khan Bizenjo          Amun Taraqqi Party    162
# 19715           Shakeel Ahmed                 Independent    338
# 19716     Wazeer Ahmed Norani  Tehreek-e-Labbaik Pakistan   4604
#
#       Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# 19712
# 19713
# 19714
# 19715
# 19716
#
#       Total_Registered_Voters Turnout  Election
# 19712                          56.02%      2018
# ...

# %%
df1.drop('S.No', axis=1, inplace=True)
df2.drop('Unnamed: 0', axis=1, inplace=True)
df3.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df1.head(3)
# Out:
#          Seat Constituency_title                  Candidate_Name   Party  \
# 0  Peshawar I               NA-1         Muhammad Yousaf Khattak  PML(Q)
# 1  Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan     PNA
# 2  Peshawar I               NA-1                       Jan Akbar     IND
#
#    Votes Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# 0  44507             79847                 2688       82535
# 1  33964             79847                 2688       82535
# 2   1376             79847                 2688       82535
#
#   Total_Registered_Voters Turnout  Election
# 0                  150063    0.55      1977
# 1                  150063    0.55      1977
# 2                  150063    0.55      1977

# %%
df2.head(3)
# Out:
#          Seat Constituency_title                  Candidate_Name   Party  \
# 0  Peshawar I               NA-1         Muhammad Yousaf Khattak  PML(Q)
# 1  Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan     PNA
# 2  Peshawar I               NA-1                       Jan Akbar     IND
#
#    Votes Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# 0  44507             79847                 2688       82535
# 1  33964             79847                 2688       82535
# 2   1376             79847                 2688       82535
#
#   Total_Registered_Voters Turnout  Election
# 0                  150063    0.55      1977
# 1                  150063    0.55      1977
# 2                  150063    0.55      1977

# %%
df = pd.concat([df1,df2])

# %%
df
# Out:
#                       Seat Constituency_title                  Candidate_Name  \
# 0               Peshawar I               NA-1         Muhammad Yousaf Khattak
# 1               Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan
# 2               Peshawar I               NA-1                       Jan Akbar
# 3              Peshawar II               NA-2    Arbab Mohammad Jehandir Khan
# 4              Peshawar II               NA-2            Arbab Saif-ur-Rahman
# ...                    ...                ...                             ...
# 19722  Lasbela-cum-Gawadar             NA 206         Molvi M. Yaqoob Sasoli
# 19723  Lasbela-cum-Gawadar             NA 206                   Abdul Hameed
# 19724   Turbat-cum-Panjgur             NA 207     Shakeel Ahmad Baloch, Adv.
# 19725   Turbat-cum-Panjgur             NA 207            Dr. M. Yasin Baloch
# 19726   Turbat-cum-Panjgur             NA 207              Rehmatullah Molvi
#
# ...

# %%
df = pd.concat([df,df3])

# %%
df.head(10)
# Out:
#            Seat Constituency_title                   Candidate_Name    Party  \
# 0    Peshawar I               NA-1          Muhammad Yousaf Khattak   PML(Q)
# 1    Peshawar I               NA-1   Air Marshal (Retd) Asghar Khan      PNA
# 2    Peshawar I               NA-1                        Jan Akbar      IND
# 3   Peshawar II               NA-2     Arbab Mohammad Jehandir Khan      PPP
# 4   Peshawar II               NA-2             Arbab Saif-ur-Rahman      PNA
# 5   Peshawar II               NA-2                    M. Nazirullah  PML (Q)
# 6   Peshawar II               NA-2  Sqr. Leader (R) Qazi Shah Jehan      IND
# 7   Peshawar II               NA-2                    M. Aslam Khan      IND
# 8  Peshawar III               NA-3                 Aftab Ahmed Khan      PPP
# 9  Peshawar III               NA-3       Sardar Sherbaz Khan Mazari      PNA
#
#    Votes Total_Valid_Votes Total_Rejected_Votes Total_Votes  \
# ...

# %%
print("length of df1 = ", len(df1))
print("length of df2 = ", len(df2))
print("length of df3 = ", len(df3))

if (len(df1)+len(df2)+len(df3)) == len(df):
    print("All records concatenated")
else:
    print("Not All records concatenated")
# Out:
# length of df1 =  19727
# length of df2 =  19727
# length of df3 =  19717
# All records concatenated

# %%
df.isnull().sum()
# Out:
# Seat                       6876
# Constituency_title            0
# Candidate_Name               12
# Party                      3318
# Votes                      7609
# Total_Valid_Votes          7791
# Total_Rejected_Votes       7791
# Total_Votes                8800
# Total_Registered_Voters    7117
# Turnout                    7806
# Election                      0
# dtype: int64

# %%
len(df)
# Out:
# 59171

# %%
(59171 * 20)/100
# Out:
# 11834.2

# %% [markdown]
# So if we have more than 11800 NaN values we will be removing those rows because it will skew over data, but according to the nature of this problem, we will be asking business domain experts, how to treat with this data!
#
# BUT WAIT ! ! !
#
# maybe it is not counting the empty cells, but only NaNs

# %%
import numpy as np

# %%
df.replace(' ', np.nan, inplace=True)

# %%
df
# Out:
#                      Seat Constituency_title                  Candidate_Name  \
# 0              Peshawar I               NA-1         Muhammad Yousaf Khattak
# 1              Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan
# 2              Peshawar I               NA-1                       Jan Akbar
# 3             Peshawar II               NA-2    Arbab Mohammad Jehandir Khan
# 4             Peshawar II               NA-2            Arbab Saif-ur-Rahman
# ...                   ...                ...                             ...
# 19712  Lasbela-cum-Gwadar             NA-272                  Mohammad Akram
# 19713  Lasbela-cum-Gwadar             NA-272          Muhammad Akhtar mengal
# 19714  Lasbela-cum-Gwadar             NA-272              Nawab Khan Bizenjo
# 19715  Lasbela-cum-Gwadar             NA-272                   Shakeel Ahmed
# 19716  Lasbela-cum-Gwadar             NA-272             Wazeer Ahmed Norani
#
# ...

# %%
df.isnull().sum()
# Out:
# Seat                        6876
# Constituency_title             0
# Candidate_Name                12
# Party                       3318
# Votes                       7609
# Total_Valid_Votes          10940
# Total_Rejected_Votes       10941
# Total_Votes                11948
# Total_Registered_Voters    10265
# Turnout                     7806
# Election                       0
# dtype: int64

# %% [markdown]
# Now, re-calculate the equation

# %%
len(df)
# Out:
# 59171

# %%
(59171 * 20)/100
# Out:
# 11834.2

# %% [markdown]
# Now, according to this we'll need to delete Total_Votes columns OR we'll be increasing the our threshold amount, like above than 20% or 25%. Let's stick to our policy! 20%

# %%
df.drop('Total_Votes', axis=1, inplace=True)

# %%
df.replace(' NA', np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# Seat                        6876
# Constituency_title             0
# Candidate_Name                12
# Party                       3318
# Votes                       7631
# Total_Valid_Votes          10940
# Total_Rejected_Votes       10941
# Total_Registered_Voters    10265
# Turnout                     7806
# Election                       0
# dtype: int64

# %% [markdown]
# Just notice Votes in this output & in previous output.

# %%
df.replace(' NA ', np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# Seat                        6876
# Constituency_title             0
# Candidate_Name                12
# Party                       3318
# Votes                       7635
# Total_Valid_Votes          10940
# Total_Rejected_Votes       10941
# Total_Registered_Voters    10265
# Turnout                     7806
# Election                       0
# dtype: int64

# %% [markdown]
# Just notice Votes in this output & in previous output.
# 7631 earlier, now 7635

# %%
df.where(df == 'NaN')
# Out:
# /home/umair/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#       Seat Constituency_title Candidate_Name Party Votes Total_Valid_Votes  \
# 0      NaN                NaN            NaN   NaN   NaN               NaN
# 1      NaN                NaN            NaN   NaN   NaN               NaN
# 2      NaN                NaN            NaN   NaN   NaN               NaN
# 3      NaN                NaN            NaN   NaN   NaN               NaN
# 4      NaN                NaN            NaN   NaN   NaN               NaN
# ...    ...                ...            ...   ...   ...               ...
# 19712  NaN                NaN            NaN   NaN   NaN               NaN
# 19713  NaN                NaN            NaN   NaN   NaN               NaN
# ...

# %%
cols = list(df.columns)

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values = np.nan, strategy='most_frequent')

a = imp.fit_transform(df)

# %%
df = pd.DataFrame(a)

# %%
df.columns = cols

# %%
df.head()
# Out:
#           Seat Constituency_title                  Candidate_Name   Party  \
# 0   Peshawar I               NA-1         Muhammad Yousaf Khattak  PML(Q)
# 1   Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan     PNA
# 2   Peshawar I               NA-1                       Jan Akbar     IND
# 3  Peshawar II               NA-2    Arbab Mohammad Jehandir Khan     PPP
# 4  Peshawar II               NA-2            Arbab Saif-ur-Rahman     PNA
#
#    Votes Total_Valid_Votes Total_Rejected_Votes Total_Registered_Voters  \
# 0  44507             79847                 2688                  150063
# 1  33964             79847                 2688                  150063
# 2   1376             79847                 2688                  150063
# 3  32247             65825                 2155                  129733
# 4  30268             65825                 2155                  129733
#
#   Turnout Election
# 0    0.55     1977
# 1    0.55     1977
# 2    0.55     1977
# ...

# %% [raw]
# colsWithAllNullValues = df.columns[df.isnull().all()].tolist()
# data.query('Senior_Management == True
#             and Gender =="Male" and Team =="Marketing"
#             and First_Name =="Johnny"', inplace = True)
# data.drop_duplicates(subset ="First Name",
#                      keep = False, inplace = True)
#
# # idhar hum rows add krdeingy duplicated ta ke show hojae data duplication remove hoti hui.
#
# names= list(dataframe) # for extracting cols names
# rf = RandomForestRegressor()
# rf.fit(X, y)
# print (sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names),
#              reverse=True))

# %% [markdown]
# Now, this below features are important when we have to delete all columns which contain every value as NaN or some
# values as NaN, so that we've the names of columns where we can perform dropping.

# %%
colsWithAllNullValues = df.columns[df.isnull().all()].tolist()

# %%
colsWithAllNullValues
# Out:
# []

# %%
colsWithAllNullValues = df.columns[df.isnull().any()].tolist()

# %%
colsWithAllNullValues
# Out:
# []

# %%
len(df)
# Out:
# 59171

# %%
df.drop_duplicates(subset = cols, keep = 'first', inplace = True)

# %%
len(df)
# Out:
# 36035

# %%
df.columns
# Out:
# Index(['Seat', 'Constituency_title', 'Candidate_Name', 'Party', 'Votes',
#        'Total_Valid_Votes', 'Total_Rejected_Votes', 'Total_Registered_Voters',
#        'Turnout', 'Election'],
#       dtype='object')

# %%
from sklearn.ensemble.RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X, y)
print (sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), names), 
             reverse=True))

# %%
df
# Out:
#                      Seat Constituency_title                  Candidate_Name  \
# 0              Peshawar I               NA-1         Muhammad Yousaf Khattak
# 1              Peshawar I               NA-1  Air Marshal (Retd) Asghar Khan
# 2              Peshawar I               NA-1                       Jan Akbar
# 3             Peshawar II               NA-2    Arbab Mohammad Jehandir Khan
# 4             Peshawar II               NA-2            Arbab Saif-ur-Rahman
# ...                   ...                ...                             ...
# 59166  Lasbela-cum-Gwadar             NA-272                  Mohammad Akram
# 59167  Lasbela-cum-Gwadar             NA-272          Muhammad Akhtar mengal
# 59168  Lasbela-cum-Gwadar             NA-272              Nawab Khan Bizenjo
# 59169  Lasbela-cum-Gwadar             NA-272                   Shakeel Ahmed
# 59170  Lasbela-cum-Gwadar             NA-272             Wazeer Ahmed Norani
#
# ...

# %%
df.query('Seat == "Peshawar I" and Constituency_title == "NA-1"', inplace = True)

# %%
df
# Out:
#             Seat Constituency_title                     Candidate_Name  \
# 0     Peshawar I               NA-1            Muhammad Yousaf Khattak
# 1     Peshawar I               NA-1     Air Marshal (Retd) Asghar Khan
# 2     Peshawar I               NA-1                          Jan Akbar
# 741   Peshawar I               NA-1         Haji Mohammad Younis Elahi
# 742   Peshawar I               NA-1                Zafar Ali Shah Syed
# 743   Peshawar I               NA-1                        M. Khurshid
# 744   Peshawar I               NA-1  Maj. (R) Sultan Hussain Shah Syed
# 1839  Peshawar I               NA-1           Aftab Ahmed Khan Sherpao
# 1840  Peshawar I               NA-1                Ghulam Ahmed Bilour
# 1841  Peshawar I               NA-1                           M. Rafiq
# 1842  Peshawar I               NA-1                         Said Anwar
#
#             Party  Votes Total_Valid_Votes Total_Rejected_Votes  \
# ...

# %%
df1.columns[-1]
# Out:
# 'Election'

# %%
df1[df1.columns[-1]]
# Out:
# 0        1977
# 1        1977
# 2        1977
# 3        1977
# 4        1977
#          ...
# 19722    1997
# 19723    1997
# 19724    1997
# 19725    1997
# 19726    1997
# Name: Election, Length: 19727, dtype: int64
