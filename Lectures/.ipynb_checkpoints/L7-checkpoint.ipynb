# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('Titanic/train.csv')
data=data.drop(['Name', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1)
y=data['Survived'].values
data=data.drop('Survived', axis=1)
data['Age']=data['Age'].fillna(data['Age'].median())
data['Age']=pd.to_numeric(data['Age'], errors='coerce')
d = {'male': '0',
     'female': '1',
    }
data.Sex=data.Sex.map(d)
data['Sex']=pd.to_numeric(data['Sex'], errors='coerce')
#print(data)

test_data=pd.read_csv('Titanic/test.csv')
test_data=test_data.drop(['Name', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1)
test_data['Age']=test_data['Age'].fillna(test_data['Age'].median())
test_data['Age']=pd.to_numeric(test_data['Age'], errors='coerce')
d = {'male': '0',
     'female': '1',
    }
test_data.Sex=test_data.Sex.map(d)
test_data['Sex']=pd.to_numeric(test_data['Sex'], errors='coerce')

X_train, X_test, y_train,y_test = train_test_split(data,y,test_size=0.3,random_state=21,stratify=y)
#Controls the shuffling applied to the data before applying the split.
#Pass an int for reproducible output across multiple function calls

knn= GaussianNB()
knn.fit(X_train, y_train)
prediction=knn.predict(X_test)

print("Accuracy of Classifier = ",accuracy_score(y_test,prediction))
# Out:
# Accuracy of Classifier =  0.7723880597014925

# %%
X_train, X_test, y_train,y_test = train_test_split(data,y, test_size=0.3, random_state=21)

knn= GaussianNB()
knn.fit(X_train, y_train)
prediction=knn.predict(X_test)

print("Accuracy of Classifier = ",accuracy_score(y_test,prediction))
# Out:
# Accuracy of Classifier =  0.7910447761194029

# %%
from sklearn.svm import SVC
svc= SVC()
svc.fit(X_train, y_train)
prediction=svc.predict(X_test)

print("Accuracy of Classifier = ",accuracy_score(y_test,prediction))
# Out:
# Accuracy of Classifier =  0.6007462686567164

# %% [markdown]
# ## Classification Report & Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[136,  25],
#        [ 31,  76]])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83       161
#            1       0.75      0.71      0.73       107
#
#     accuracy                           0.79       268
#    macro avg       0.78      0.78      0.78       268
# weighted avg       0.79      0.79      0.79       268

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_results = cross_val_score(knn, data, y, cv = 5)

# %%
cv_results
# Out:
# array([0.79329609, 0.79213483, 0.79213483, 0.75842697, 0.78651685])

# %%
cv_results.mean()
# Out:
# 0.7845019145063086

# %% [markdown]
# ## Hyper Parameter Tuning

# %% [markdown]
# https://www.quora.com/What-is-the-difference-between-random-search-and-grid-search-for-hyperparameter-optimization

# %% [markdown]
# ## Regularization

# %% [markdown]
# ![Screenshot%20from%202020-09-24%2014-40-32.png](attachment:Screenshot%20from%202020-09-24%2014-40-32.png)
